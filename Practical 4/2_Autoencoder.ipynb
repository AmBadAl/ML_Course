# %% [markdown]
# <img src='http://www-scf.usc.edu/~ghasemig/images/sharif.png' alt="SUT logo" width=200 height=200 align=left class="saturate" >
#
# <br>
# <font face="Times New Roman">
# <div dir=ltr align=center>
# <font color=0F5298 size=7>
#     Introduction to Machine Learning <br>
# <font color=2565AE size=5>
#     Computer Engineering Department <br>
#     Fall 2022<br>
# <font color=3C99D size=5>
#     Homework 3: Practical - Neural Network <br>
# <font color=696880 size=4>
#     Alireza Belal
#
#
# ____

# %% [markdown]
# ### Full Name : Amirreza Bagheri Delouee
# ### Student Number : 98109804
# ___

# %% [markdown]
# # Setup

# %% [markdown]
# # 0. Preparation
#
# In this part, you will use a dataset related to COVID-19. Load your dataset using pandas.

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

covid_data = pd.read_csv('Covid Dataset.csv')
categorical_feature_mask = covid_data.dtypes == object
cateforical_cols = covid_data.columns[categorical_feature_mask].tolist()
le = LabelEncoder()
covid_data[cateforical_cols] = covid_data[cateforical_cols].apply(lambda col: le.fit_transform(col))
covid_data = covid_data.astype(float)

# Extract X and Y from the dataset
X_total = covid_data.iloc[:, 0:20].values
y_total = covid_data.iloc[:, 20].values


#SPLIT THE DATA INTO TRAIN AND TEST DATA 
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_total, y_total, test_size = 0.3, random_state = 0)

# %% [markdown]
# ---------------

# %% [markdown]
# # 1. DNN as nonlinear dimensionality reduction method (50 Points)
#
# Autoencoder is an unsupervised artificial neural network that compresses the data to lower dimension and then reconstructs the input back. Autoencoder finds the representation of the data in a lower dimension by focusing more on the important features getting rid of noise and redundancy. It's based on Encoder-Decoder architecture, where encoder encodes the high-dimensional data to lower-dimension and decoder takes the lower-dimensional data and tries to reconstruct the original high-dimensional data.
#
# ![picture](https://drive.google.com/uc?id=1RTZwx4xL6zFV_nUENBgWlFKLKldPoyI-)
#
# In the above Diagram, X is the input data, z is the lower-dimension representation of input X and X’ is the reconstructed input data. The mapping of higher to lower dimensions can be linear or non-linear depending on the choice of the activation function.
#
# In this part you're gonna implement an autoencoder using Keras framework as dimensionally reduction module as explained [here](https://blog.keras.io/building-autoencoders-in-keras.html).
# (It would be ok to use PyTorch as well.)
# Reduce the dimension of the data to 2 dimensions and visualize the low-dimensional data.

# %%
# import necessary libraries
from keras import Input
from keras.models import Sequential, Model
from keras.layers import Dense
from keras.optimizers import Adam

# %%
# define layers (25 Points)
input_dim = Input(shape=(X_train.shape[1], ))
encoded = Dense(16, activation='relu')(input_dim)
encoded = Dense(8, activation='relu')(encoded)
encoded = Dense(4, activation='relu')(encoded)
encoded = Dense(2)(encoded)

decoded = Dense(4, activation='relu')(encoded)
decoded = Dense(8, activation='relu')(decoded)
decoded = Dense(16, activation='relu')(decoded)
decoded = Dense(20, activation='sigmoid')(decoded)

autoencoder = Model(input_dim, decoded)
autoencoder.compile(optimizer='adam', loss='mean_squared_error')

autoencoder.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 20)]              0
#
#  dense_8 (Dense)             (None, 16)                336
#
#  dense_9 (Dense)             (None, 8)                 136
#
#  dense_10 (Dense)            (None, 4)                 36
#
#  dense_11 (Dense)            (None, 2)                 10
#
#  dense_12 (Dense)            (None, 4)                 12
#
#  dense_13 (Dense)            (None, 8)                 40
#
#  dense_14 (Dense)            (None, 16)                144
#
#  dense_15 (Dense)            (None, 20)                340
#
# =================================================================
# Total params: 1,054
# Trainable params: 1,054
# Non-trainable params: 0
# _________________________________________________________________

# %%
# train the model and reduce the dimension of the data (15 Points)
autoencoder.fit(X_train, X_train,
                epochs = 100,
                batch_size = 16,
                shuffle = True,
                validation_data = (X_test, X_test))

encoder = Model(input_dim, encoded)
encoded_train = pd.DataFrame(encoder.predict(X_train))
# Out:
# Epoch 1/100
# 238/238 [==============================] - 1s 3ms/step - loss: 0.2244 - val_loss: 0.1990
# Epoch 2/100
# 238/238 [==============================] - 1s 4ms/step - loss: 0.1887 - val_loss: 0.1804
# Epoch 3/100
# 238/238 [==============================] - 1s 5ms/step - loss: 0.1771 - val_loss: 0.1756
# Epoch 4/100
# 238/238 [==============================] - 1s 5ms/step - loss: 0.1738 - val_loss: 0.1736
# Epoch 5/100
# 238/238 [==============================] - 1s 3ms/step - loss: 0.1717 - val_loss: 0.1719
# Epoch 6/100
# 238/238 [==============================] - 1s 3ms/step - loss: 0.1702 - val_loss: 0.1711
# Epoch 7/100
# 238/238 [==============================] - 1s 3ms/step - loss: 0.1688 - val_loss: 0.1697
# Epoch 8/100
# 238/238 [==============================] - 1s 3ms/step - loss: 0.1676 - val_loss: 0.1688
# Epoch 9/100
# 238/238 [==============================] - 1s 3ms/step - loss: 0.1667 - val_loss: 0.1682
# Epoch 10/100
# 238/238 [==============================] - 1s 3ms/step - loss: 0.1660 - val_loss: 0.1676
# Epoch 11/100
# 238/238 [==============================] - 1s 3ms/step - loss: 0.1653 - val_loss: 0.1668
# Epoch 12/100
# 238/238 [==============================] - 1s 3ms/step - loss: 0.1647 - val_loss: 0.1661
# Epoch 13/100
# 238/238 [==============================] - 1s 3ms/step - loss: 0.1639 - val_loss: 0.1657
# Epoch 14/100
# 238/238 [==============================] - 1s 3ms/step - loss: 0.1632 - val_loss: 0.1647
# Epoch 15/100
# 238/238 [==============================] - 1s 3ms/step - loss: 0.1625 - val_loss: 0.1643
# Epoch 16/100
# 238/238 [==============================] - 1s 3ms/step - loss: 0.1618 - val_loss: 0.1632
# Epoch 17/100
# 238/238 [==============================] - 1s 3ms/step - loss: 0.1611 - val_loss: 0.1627
# Epoch 18/100
# 238/238 [==============================] - 1s 3ms/step - loss: 0.1605 - val_loss: 0.1624
# Epoch 19/100
# 238/238 [==============================] - 1s 3ms/step - loss: 0.1598 - val_loss: 0.1612
# Epoch 20/100
# 238/238 [==============================] - 1s 5ms/step - loss: 0.1592 - val_loss: 0.1605
# Epoch 21/100
# 238/238 [==============================] - 1s 4ms/step - loss: 0.1587 - val_loss: 0.1596
# Epoch 22/100
# 238/238 [==============================] - 1s 3ms/step - loss: 0.1579 - val_loss: 0.1592
# Epoch 23/100
# 238/238 [==============================] - 1s 3ms/step - loss: 0.1575 - val_loss: 0.1589
# Epoch 24/100
# 238/238 [==============================] - 1s 3ms/step - loss: 0.1570 - val_loss: 0.1583
# Epoch 25/100
# 238/238 [==============================] - 1s 3ms/step - loss: 0.1564 - val_loss: 0.1583
# Epoch 26/100
# 238/238 [==============================] - 1s 3ms/step - loss: 0.1558 - val_loss: 0.1572
# Epoch 27/100
# 238/238 [==============================] - 1s 3ms/step - loss: 0.1554 - val_loss: 0.1563
# Epoch 28/100
# 238/238 [==============================] - 1s 4ms/step - loss: 0.1547 - val_loss: 0.1556
# Epoch 29/100
# 238/238 [==============================] - 1s 3ms/step - loss: 0.1542 - val_loss: 0.1555
# Epoch 30/100
# 238/238 [==============================] - 1s 4ms/step - loss: 0.1537 - val_loss: 0.1547
# Epoch 31/100
# 238/238 [==============================] - 1s 3ms/step - loss: 0.1532 - val_loss: 0.1541
# Epoch 32/100
# 238/238 [==============================] - 1s 3ms/step - loss: 0.1527 - val_loss: 0.1541
# Epoch 33/100
# 238/238 [==============================] - 1s 3ms/step - loss: 0.1523 - val_loss: 0.1532
# Epoch 34/100
# 238/238 [==============================] - 1s 3ms/step - loss: 0.1518 - val_loss: 0.1524
# Epoch 35/100
# 238/238 [==============================] - 1s 3ms/step - loss: 0.1509 - val_loss: 0.1522
# Epoch 36/100
# 238/238 [==============================] - 1s 4ms/step - loss: 0.1505 - val_loss: 0.1515
# Epoch 37/100
# 238/238 [==============================] - 1s 5ms/step - loss: 0.1502 - val_loss: 0.1512
# Epoch 38/100
# 238/238 [==============================] - 1s 4ms/step - loss: 0.1493 - val_loss: 0.1507
# Epoch 39/100
# 238/238 [==============================] - 1s 3ms/step - loss: 0.1489 - val_loss: 0.1499
# Epoch 40/100
# 238/238 [==============================] - 1s 3ms/step - loss: 0.1485 - val_loss: 0.1497
# Epoch 41/100
# 238/238 [==============================] - 1s 2ms/step - loss: 0.1484 - val_loss: 0.1493
# Epoch 42/100
# 238/238 [==============================] - 1s 3ms/step - loss: 0.1478 - val_loss: 0.1490
# Epoch 43/100
# 238/238 [==============================] - 1s 3ms/step - loss: 0.1473 - val_loss: 0.1489
# Epoch 44/100
# 238/238 [==============================] - 1s 3ms/step - loss: 0.1468 - val_loss: 0.1475
# Epoch 45/100
# 238/238 [==============================] - 1s 3ms/step - loss: 0.1465 - val_loss: 0.1475
# Epoch 46/100
# 238/238 [==============================] - 1s 4ms/step - loss: 0.1460 - val_loss: 0.1468
# Epoch 47/100
# 238/238 [==============================] - 1s 4ms/step - loss: 0.1456 - val_loss: 0.1468
# Epoch 48/100
# 238/238 [==============================] - 1s 3ms/step - loss: 0.1455 - val_loss: 0.1494
# Epoch 49/100
# 238/238 [==============================] - 1s 2ms/step - loss: 0.1452 - val_loss: 0.1473
# Epoch 50/100
# 238/238 [==============================] - 1s 3ms/step - loss: 0.1449 - val_loss: 0.1456
# Epoch 51/100
# 238/238 [==============================] - 1s 2ms/step - loss: 0.1445 - val_loss: 0.1458
# Epoch 52/100
# 238/238 [==============================] - 1s 4ms/step - loss: 0.1439 - val_loss: 0.1455
# Epoch 53/100
# 238/238 [==============================] - 1s 4ms/step - loss: 0.1437 - val_loss: 0.1450
# Epoch 54/100
# 238/238 [==============================] - 1s 5ms/step - loss: 0.1438 - val_loss: 0.1456
# Epoch 55/100
# 238/238 [==============================] - 1s 3ms/step - loss: 0.1436 - val_loss: 0.1451
# Epoch 56/100
# 238/238 [==============================] - 1s 3ms/step - loss: 0.1435 - val_loss: 0.1446
# Epoch 57/100
# 238/238 [==============================] - 1s 2ms/step - loss: 0.1428 - val_loss: 0.1445
# Epoch 58/100
# 238/238 [==============================] - 1s 2ms/step - loss: 0.1429 - val_loss: 0.1441
# Epoch 59/100
# 238/238 [==============================] - 1s 3ms/step - loss: 0.1425 - val_loss: 0.1434
# Epoch 60/100
# 238/238 [==============================] - 1s 3ms/step - loss: 0.1421 - val_loss: 0.1442
# Epoch 61/100
# 238/238 [==============================] - 1s 3ms/step - loss: 0.1422 - val_loss: 0.1436
# Epoch 62/100
# 238/238 [==============================] - 1s 3ms/step - loss: 0.1418 - val_loss: 0.1431
# Epoch 63/100
# 238/238 [==============================] - 1s 3ms/step - loss: 0.1417 - val_loss: 0.1430
# Epoch 64/100
# 238/238 [==============================] - 1s 3ms/step - loss: 0.1418 - val_loss: 0.1447
# Epoch 65/100
# 238/238 [==============================] - 1s 3ms/step - loss: 0.1416 - val_loss: 0.1432
# Epoch 66/100
# 238/238 [==============================] - 1s 3ms/step - loss: 0.1415 - val_loss: 0.1424
# Epoch 67/100
# 238/238 [==============================] - 1s 2ms/step - loss: 0.1413 - val_loss: 0.1433
# Epoch 68/100
# 238/238 [==============================] - 1s 3ms/step - loss: 0.1414 - val_loss: 0.1437
# Epoch 69/100
# 238/238 [==============================] - 1s 3ms/step - loss: 0.1410 - val_loss: 0.1435
# Epoch 70/100
# 238/238 [==============================] - 1s 4ms/step - loss: 0.1409 - val_loss: 0.1420
# Epoch 71/100
# 238/238 [==============================] - 1s 5ms/step - loss: 0.1407 - val_loss: 0.1418
# Epoch 72/100
# 238/238 [==============================] - 1s 5ms/step - loss: 0.1408 - val_loss: 0.1417
# Epoch 73/100
# 238/238 [==============================] - 1s 3ms/step - loss: 0.1405 - val_loss: 0.1416
# Epoch 74/100
# 238/238 [==============================] - 1s 3ms/step - loss: 0.1404 - val_loss: 0.1425
# Epoch 75/100
# 238/238 [==============================] - 1s 3ms/step - loss: 0.1404 - val_loss: 0.1426
# Epoch 76/100
# 238/238 [==============================] - 1s 3ms/step - loss: 0.1404 - val_loss: 0.1408
# Epoch 77/100
# 238/238 [==============================] - 1s 2ms/step - loss: 0.1401 - val_loss: 0.1412
# Epoch 78/100
# 238/238 [==============================] - 1s 3ms/step - loss: 0.1400 - val_loss: 0.1416
# Epoch 79/100
# 238/238 [==============================] - 1s 3ms/step - loss: 0.1398 - val_loss: 0.1409
# Epoch 80/100
# 238/238 [==============================] - 1s 3ms/step - loss: 0.1398 - val_loss: 0.1416
# Epoch 81/100
# 238/238 [==============================] - 1s 3ms/step - loss: 0.1401 - val_loss: 0.1412
# Epoch 82/100
# 238/238 [==============================] - 1s 3ms/step - loss: 0.1396 - val_loss: 0.1409
# Epoch 83/100
# 238/238 [==============================] - 1s 3ms/step - loss: 0.1395 - val_loss: 0.1418
# Epoch 84/100
# 238/238 [==============================] - 1s 3ms/step - loss: 0.1396 - val_loss: 0.1408
# Epoch 85/100
# 238/238 [==============================] - 1s 3ms/step - loss: 0.1391 - val_loss: 0.1408
# Epoch 86/100
# 238/238 [==============================] - 1s 3ms/step - loss: 0.1395 - val_loss: 0.1417
# Epoch 87/100
# 238/238 [==============================] - 1s 4ms/step - loss: 0.1390 - val_loss: 0.1398
# Epoch 88/100
# 238/238 [==============================] - 1s 4ms/step - loss: 0.1391 - val_loss: 0.1412
# Epoch 89/100
# 238/238 [==============================] - 1s 4ms/step - loss: 0.1387 - val_loss: 0.1413
# Epoch 90/100
# 238/238 [==============================] - 1s 4ms/step - loss: 0.1387 - val_loss: 0.1400
# Epoch 91/100
# 238/238 [==============================] - 1s 3ms/step - loss: 0.1385 - val_loss: 0.1405
# Epoch 92/100
# 238/238 [==============================] - 1s 2ms/step - loss: 0.1386 - val_loss: 0.1399
# Epoch 93/100
# 238/238 [==============================] - 1s 3ms/step - loss: 0.1382 - val_loss: 0.1402
# Epoch 94/100
# 238/238 [==============================] - 1s 3ms/step - loss: 0.1382 - val_loss: 0.1391
# Epoch 95/100
# 238/238 [==============================] - 1s 3ms/step - loss: 0.1389 - val_loss: 0.1396
# Epoch 96/100
# 238/238 [==============================] - 1s 3ms/step - loss: 0.1385 - val_loss: 0.1390
# Epoch 97/100
# 238/238 [==============================] - 1s 3ms/step - loss: 0.1380 - val_loss: 0.1397
# Epoch 98/100
# 238/238 [==============================] - 1s 3ms/step - loss: 0.1383 - val_loss: 0.1394
# Epoch 99/100
# 238/238 [==============================] - 1s 3ms/step - loss: 0.1379 - val_loss: 0.1398
# Epoch 100/100
# 238/238 [==============================] - 1s 3ms/step - loss: 0.1383 - val_loss: 0.1393
# 119/119 [==============================] - 0s 2ms/step

# %%
encoded_train
# Out:
#               0         1
# 0     -0.033778  0.362856
# 1      6.140566 -2.459049
# 2     19.081629 -7.146616
# 3     21.687229 -8.345786
# 4      5.260708 -2.370869
# ...         ...       ...
# 3798 -12.573806 -5.392723
# 3799   3.073459 -1.878410
# 3800   6.318044 -3.691677
# 3801   3.465932 -2.311224
# 3802   5.946725 -2.557783
#
# [3803 rows x 2 columns]

# %%
# Plot the encoded data (10 Points)
import matplotlib.pyplot as plt

plt.scatter(encoded_train[0], encoded_train[1], c=y_train)
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.show()
